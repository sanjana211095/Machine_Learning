# %%
#Importing required libaries

import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Task 1

# %%
df=pd.DataFrame({'Name':['Ravi','Hari','Manu'],'Department':['Sales','Account','Purchase']})
df
# Out:
#    Name Department
# 0  Ravi      Sales
# 1  Hari    Account
# 2  Manu   Purchase

# %%
Department=pd.get_dummies(df.Department,dtype=int)
Department
# Out:
#    Account  Purchase  Sales
# 0        0         0      1
# 1        1         0      0
# 2        0         1      0

# %%
df1=pd.concat([df,Department],axis=1)
df1
# Out:
#    Name Department  Account  Purchase  Sales
# 0  Ravi      Sales        0         0      1
# 1  Hari    Account        1         0      0
# 2  Manu   Purchase        0         1      0

# %%
df1["dept1"]=df1['Department'].map({'Sales':1,'Account':2,'Purchase':3})
df1
# Out:
#    Name Department  Account  Purchase  Sales  dept1
# 0  Ravi      Sales        0         0      1      1
# 1  Hari    Account        1         0      0      2
# 2  Manu   Purchase        0         1      0      3

# %%
df1["dept2"] =df1['Department'].map({'Sales':0.1,'Account':0.2,'Purchase':0.3})
df1
# Out:
#    Name Department  Account  Purchase  Sales  dept1  dept2
# 0  Ravi      Sales        0         0      1      1    0.1
# 1  Hari    Account        1         0      0      2    0.2
# 2  Manu   Purchase        0         1      0      3    0.3

# %% [markdown]
# # Task 2

# %%
df1['Department']=df1['Department'].str.upper()
df1
# Out:
#    Name Department  Account  Purchase  Sales  dept1  dept2
# 0  Ravi      SALES        0         0      1      1    0.1
# 1  Hari    ACCOUNT        1         0      0      2    0.2
# 2  Manu   PURCHASE        0         1      0      3    0.3

# %% [markdown]
# # Task 3

# %%
name=pd.DataFrame({"Fullname":["Sanjana Rajendra Bafana","Sanjana Shubham Kucheriya","Sanjana Rajendra Jain"]})
name
# Out:
#                     Fullname
# 0    Sanjana Rajendra Bafana
# 1  Sanjana Shubham Kucheriya
# 2      Sanjana Rajendra Jain

# %%
names=name['Fullname'].str.split(" ",expand=True)
names.columns =["First","Middle","Last"]
names
# Out:
#      First    Middle       Last
# 0  Sanjana  Rajendra     Bafana
# 1  Sanjana   Shubham  Kucheriya
# 2  Sanjana  Rajendra       Jain

# %%
Details=pd.concat([name,names],axis=1)
Details
# Out:
#                     Fullname    First    Middle       Last
# 0    Sanjana Rajendra Bafana  Sanjana  Rajendra     Bafana
# 1  Sanjana Shubham Kucheriya  Sanjana   Shubham  Kucheriya
# 2      Sanjana Rajendra Jain  Sanjana  Rajendra       Jain

# %% [markdown]
# # Task 4

# %%
House=pd.read_csv("kc_house_data.csv")
House
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# !pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 24.6/24.6 MB 3.2 MB/s eta 0:00:00
# ...

# %%
House.to_parquet("House.parquet",index=False)

# %%
House.to_feather("House.feather")

# %% [markdown]
# # Task 5

# %%
import time

# %%
start = time.time()
alst = list(range(1,999999))
newlst = []
newlst = [e*e for e in alst]
end =time.time()
print("Time Took:" ,end-start)
# Out:
# Time Took: 0.10188531875610352

# %%
start1 =time.time()
alst = list(range(1,999999))
newlst = []
for elem in alst:
    newlst.append(elem*elem)
end1 =time.time()
print("Time Took:" ,end1-start1)
# Out:
# Time Took: 0.2018601894378662

# %%
start2 =time.time()
alst = list(range(1,999999))
newlst = []
newlst = list(map(lambda x : x*x, alst))
end2 =time.time()
print("Time Took:" ,end2-start2)
# Out:
# Time Took: 0.12209725379943848

# %% [markdown]
# # Task 6

# %%
data=[['t1',10,20],['t2',10,10],['t3',15,20],['t4',12,12],['t5',30,30],['t6',32,32],['t7',20,20],['t8','',''],['t9',10,""],['t10',11,11],
      ['t11','hai',20],['t12','?',30],['t13',0,0],['t13',0,0],['t15',0,'?']]

# %%
task=pd.DataFrame(data,columns=['Names','Got','Exp'])
task
# Out:
#    Names  Got Exp
# 0     t1   10  20
# 1     t2   10  10
# 2     t3   15  20
# 3     t4   12  12
# 4     t5   30  30
# 5     t6   32  32
# 6     t7   20  20
# 7     t8
# 8     t9   10
# 9    t10   11  11
# 10   t11  hai  20
# 11   t12    ?  30
# 12   t13    0   0
# 13   t13    0   0
# 14   t15    0   ?

# %%
task["Got"]=task["Got"].replace("hai","")

# %%
task["Exp"]=task["Exp"].replace("None","")

# %%
task["Exp"]=task["Exp"].replace("?","")

# %%
task["Got"]=task["Got"].replace("?","")

# %%
task=task.replace("",np.NaN)

# %%
task
# Out:
#    Names   Got   Exp
# 0     t1  10.0  20.0
# 1     t2  10.0  10.0
# 2     t3  15.0  20.0
# 3     t4  12.0  12.0
# 4     t5  30.0  30.0
# 5     t6  32.0  32.0
# 6     t7  20.0  20.0
# 7     t8   NaN   NaN
# 8     t9  10.0   NaN
# 9    t10  11.0  11.0
# 10   t11   NaN  20.0
# 11   t12   NaN  30.0
# 12   t13   0.0   0.0
# 13   t13   0.0   0.0
# 14   t15   0.0   NaN

# %%
A=task["Got"].median()
B=task["Exp"].median()

# %%
A
# Out:
# 10.5

# %%
task["Got"]=task["Got"].fillna(A)

# %%
task["Exp"]=task["Exp"].fillna(B)
task
# Out:
#    Names   Got   Exp
# 0     t1  10.0  20.0
# 1     t2  10.0  10.0
# 2     t3  15.0  20.0
# 3     t4  12.0  12.0
# 4     t5  30.0  30.0
# 5     t6  32.0  32.0
# 6     t7  20.0  20.0
# 7     t8  10.5  20.0
# 8     t9  10.0  20.0
# 9    t10  11.0  11.0
# 10   t11  10.5  20.0
# 11   t12  10.5  30.0
# 12   t13   0.0   0.0
# 13   t13   0.0   0.0
# 14   t15   0.0  20.0

# %%
task["Got"]=task["Got"].astype(int)

# %%
task["Exp"]=task["Exp"].astype(int)
task
# Out:
#    Names  Got  Exp
# 0     t1   10   20
# 1     t2   10   10
# 2     t3   15   20
# 3     t4   12   12
# 4     t5   30   30
# 5     t6   32   32
# 6     t7   20   20
# 7     t8   10   20
# 8     t9   10   20
# 9    t10   11   11
# 10   t11   10   20
# 11   t12   10   30
# 12   t13    0    0
# 13   t13    0    0
# 14   t15    0   20
